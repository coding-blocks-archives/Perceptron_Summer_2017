# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import keras
import pandas as pd

from keras.layers import Dense, Activation, Dropout
from keras.models import Sequential
from keras.utils import np_utils

# %%
ds = pd.read_csv('../data/train.csv')
print ds.shape
data = ds.values[:10000]
# Out:
# (42000, 785)

# %%
split = int(0.82 * data.shape[0])

X_train = data[:split, 1:]/255.0
X_test = data[split:, 1:]/255.0

y_train = np_utils.to_categorical(data[:split, 0])
y_test = np_utils.to_categorical(data[split:, 0])

print X_train.shape, X_test.shape
print y_train.shape, y_test.shape
# Out:
# (8200, 784) (1800, 784)
# (8200, 10) (1800, 10)

# %%
model = Sequential()

model.add(Dense(512, input_shape=(784,)))
model.add(Activation('relu'))
model.add(Dropout(0.50))

model.add(Dense(180))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(10))
model.add(Activation('softmax'))

model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 512)               401920
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 180)               92340
# _________________________________________________________________
# activation_14 (Activation)   (None, 180)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 180)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                1810
# _________________________________________________________________
# activation_15 (Activation)   (None, 10)                0
# =================================================================
# Total params: 496,070
# Trainable params: 496,070
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train,
                epochs=50,
                shuffle=True,
                batch_size=100,
                validation_data=(X_test, y_test))
# Out:
# Train on 8200 samples, validate on 1800 samples
# Epoch 1/50
# 8200/8200 [==============================] - 0s - loss: 0.7612 - acc: 0.7637 - val_loss: 0.2781 - val_acc: 0.9167
# Epoch 2/50
# 8200/8200 [==============================] - 0s - loss: 0.3119 - acc: 0.9054 - val_loss: 0.2100 - val_acc: 0.9372
# Epoch 3/50
# 8200/8200 [==============================] - 0s - loss: 0.2272 - acc: 0.9309 - val_loss: 0.1747 - val_acc: 0.9450
# Epoch 4/50
# 8200/8200 [==============================] - 0s - loss: 0.1803 - acc: 0.9441 - val_loss: 0.1653 - val_acc: 0.9461
# Epoch 5/50
# 8200/8200 [==============================] - 0s - loss: 0.1430 - acc: 0.9584 - val_loss: 0.1579 - val_acc: 0.9472
# Epoch 6/50
# 8200/8200 [==============================] - 0s - loss: 0.1179 - acc: 0.9646 - val_loss: 0.1319 - val_acc: 0.9572
# Epoch 7/50
# 8200/8200 [==============================] - 0s - loss: 0.0945 - acc: 0.9709 - val_loss: 0.1287 - val_acc: 0.9578
# Epoch 8/50
# 8200/8200 [==============================] - 0s - loss: 0.0800 - acc: 0.9765 - val_loss: 0.1378 - val_acc: 0.9550
# Epoch 9/50
# 8200/8200 [==============================] - 0s - loss: 0.0687 - acc: 0.9791 - val_loss: 0.1179 - val_acc: 0.9611
# Epoch 10/50
# 8200/8200 [==============================] - 0s - loss: 0.0609 - acc: 0.9817 - val_loss: 0.1355 - val_acc: 0.9589
# Epoch 11/50
# 8200/8200 [==============================] - 0s - loss: 0.0552 - acc: 0.9832 - val_loss: 0.1311 - val_acc: 0.9572
# Epoch 12/50
# Epoch 32/50
# 8200/8200 [==============================] - 0s - loss: 0.0209 - acc: 0.9927 - val_loss: 0.1497 - val_acc: 0.9589
# Epoch 33/50
# 8200/8200 [==============================] - 0s - loss: 0.0221 - acc: 0.9921 - val_loss: 0.1487 - val_acc: 0.9606
# Epoch 34/50
# 8200/8200 [==============================] - 0s - loss: 0.0160 - acc: 0.9951 - val_loss: 0.1558 - val_acc: 0.9633
# Epoch 35/50
# 8200/8200 [==============================] - 0s - loss: 0.0200 - acc: 0.9938 - val_loss: 0.1544 - val_acc: 0.9639
# Epoch 36/50
# 8200/8200 [==============================] - 0s - loss: 0.0156 - acc: 0.9954 - val_loss: 0.1600 - val_acc: 0.9611
# Epoch 37/50
# 8200/8200 [==============================] - 0s - loss: 0.0115 - acc: 0.9961 - val_loss: 0.1540 - val_acc: 0.9628
# Epoch 38/50
# 8200/8200 [==============================] - 0s - loss: 0.0180 - acc: 0.9948 - val_loss: 0.1701 - val_acc: 0.9622
# Epoch 39/50
# 8200/8200 [==============================] - 0s - loss: 0.0233 - acc: 0.9918 - val_loss: 0.1631 - val_acc: 0.9644
# Epoch 40/50
# 8200/8200 [==============================] - 0s - loss: 0.0195 - acc: 0.9934 - val_loss: 0.1659 - val_acc: 0.9656
# Epoch 41/50
# 8200/8200 [==============================] - 0s - loss: 0.0183 - acc: 0.9933 - val_loss: 0.1504 - val_acc: 0.9633
# Epoch 42/50
# 8200/8200 [==============================] - 0s - loss: 0.0173 - acc: 0.9945 - val_loss: 0.1613 - val_acc: 0.9678
# Epoch 43/50
# 8200/8200 [==============================] - 0s - loss: 0.0188 - acc: 0.9934 - val_loss: 0.1514 - val_acc: 0.9639
# Epoch 44/50
# 8200/8200 [==============================] - 0s - loss: 0.0161 - acc: 0.9944 - val_loss: 0.1514 - val_acc: 0.9639
# Epoch 45/50
# 8200/8200 [==============================] - 0s - loss: 0.0083 - acc: 0.9968 - val_loss: 0.1501 - val_acc: 0.9600
# Epoch 46/50
# 8200/8200 [==============================] - 0s - loss: 0.0066 - acc: 0.9978 - val_loss: 0.1602 - val_acc: 0.9672
# Epoch 47/50
# 8200/8200 [==============================] - 0s - loss: 0.0129 - acc: 0.9959 - val_loss: 0.1988 - val_acc: 0.9622
# Epoch 48/50
# 8200/8200 [==============================] - 0s - loss: 0.0132 - acc: 0.9952 - val_loss: 0.1753 - val_acc: 0.9606
# Epoch 49/50
# 8200/8200 [==============================] - 0s - loss: 0.0125 - acc: 0.9962 - val_loss: 0.1617 - val_acc: 0.9650
# Epoch 50/50
# 8200/8200 [==============================] - 0s - loss: 0.0109 - acc: 0.9966 - val_loss: 0.1700 - val_acc: 0.9650
